# %% [markdown]
# # 🚀 CapTTS Demo

# %% [markdown]
# ## 🔥 Step 1: Install packages

# %%
# Python 3.10
! pip install git+https://github.com/WangHelin1997/CapSpeech.git
# Out:
# Collecting git+https://github.com/WangHelin1997/CapSpeech.git
#   Cloning https://github.com/WangHelin1997/CapSpeech.git to /tmp/pip-req-build-bieoiv7j
#   Running command git clone --filter=blob:none --quiet https://github.com/WangHelin1997/CapSpeech.git /tmp/pip-req-build-bieoiv7j
#   Resolved https://github.com/WangHelin1997/CapSpeech.git to commit 0868f3578ba61e50ceddf4ac7b05c286c008652a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting xformers (from capspeech==0.1.0)
#   Downloading xformers-0.0.33.post2-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Collecting g2p_en (from capspeech==0.1.0)
#   Downloading g2p_en-2.1.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting laion_clap (from capspeech==0.1.0)
#   Downloading laion_clap-1.1.7-py3-none-any.whl.metadata (26 kB)
# Collecting torchvision (from capspeech==0.1.0)
#   Downloading torchvision-0.24.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (5.9 kB)
# Collecting torchaudio (from capspeech==0.1.0)
#   Downloading torchaudio-2.9.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (6.9 kB)
# Collecting torch (from capspeech==0.1.0)
#   Downloading torch-2.9.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Collecting transformers<=4.46.1,>=4.46.1 (from capspeech==0.1.0)
#   Downloading transformers-4.46.1-py3-none-any.whl.metadata (44 kB)
# Collecting tensorboard (from capspeech==0.1.0)
#   Using cached tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting datasets (from capspeech==0.1.0)
#   Downloading datasets-4.4.1-py3-none-any.whl.metadata (19 kB)
# Collecting torchmetrics (from capspeech==0.1.0)
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Collecting huggingface_hub (from capspeech==0.1.0)
#   Downloading huggingface_hub-1.2.3-py3-none-any.whl.metadata (13 kB)
# Collecting cached_path (from capspeech==0.1.0)
#   Downloading cached_path-1.8.0-py3-none-any.whl.metadata (19 kB)
# Collecting torchdiffeq (from capspeech==0.1.0)
#   Downloading torchdiffeq-0.2.5-py3-none-any.whl.metadata (440 bytes)
# Collecting x_transformers (from capspeech==0.1.0)
#   Downloading x_transformers-2.11.24-py3-none-any.whl.metadata (96 kB)
# Collecting jieba (from capspeech==0.1.0)
#   Using cached jieba-0.42.1-py3-none-any.whl
# Collecting pypinyin (from capspeech==0.1.0)
#   Downloading pypinyin-0.55.0-py2.py3-none-any.whl.metadata (12 kB)
# Collecting wandb (from capspeech==0.1.0)
#   Downloading wandb-0.23.1-py3-none-manylinux_2_28_x86_64.whl.metadata (12 kB)
# Collecting ema_pytorch (from capspeech==0.1.0)
#   Downloading ema_pytorch-0.7.7-py3-none-any.whl.metadata (689 bytes)
# Collecting sentencepiece (from capspeech==0.1.0)
#   Downloading sentencepiece-0.2.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: descript-audio-codec in /vol/home/s4181794/API/Project/api_project (from capspeech==0.1.0) (1.0.0)
# Collecting descript-audiotools@ git+https://github.com/descriptinc/audiotools (from capspeech==0.1.0)
#   Cloning https://github.com/descriptinc/audiotools to /tmp/pip-install-u367ug2q/descript-audiotools_39eb080f1ba94e7cbaba94bb749d4e5f
#   Running command git clone --filter=blob:none --quiet https://github.com/descriptinc/audiotools /tmp/pip-install-u367ug2q/descript-audiotools_39eb080f1ba94e7cbaba94bb749d4e5f
#   Resolved https://github.com/descriptinc/audiotools to commit 348ebf2034ce24e2a91a553e3171cb00c0c71678
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting protobuf>=4.0.0 (from capspeech==0.1.0)
#   Downloading protobuf-6.33.2-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting jiwer (from capspeech==0.1.0)
#   Downloading jiwer-4.0.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting accelerate (from capspeech==0.1.0)
#   Downloading accelerate-1.12.0-py3-none-any.whl.metadata (19 kB)
# Collecting evaluate (from capspeech==0.1.0)
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Collecting ninja (from capspeech==0.1.0)
#   Using cached ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Collecting packaging (from capspeech==0.1.0)
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: wheel in /vol/home/s4181794/miniconda3/envs/CapTTS/lib/python3.10/site-packages (from capspeech==0.1.0) (0.45.1)
# Requirement already satisfied: argbind in /vol/home/s4181794/.local/lib/python3.10/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0) (0.3.9)
# Collecting numpy (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting soundfile (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Downloading soundfile-0.13.1-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: pyloudnorm in /vol/home/s4181794/.local/lib/python3.10/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0) (0.1.1)
# Requirement already satisfied: importlib-resources in /vol/home/s4181794/.local/lib/python3.10/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0) (6.5.2)
# Collecting scipy (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: julius in /vol/home/s4181794/.local/lib/python3.10/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0) (0.2.7)
# Collecting ffmpy (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Downloading ffmpy-1.0.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting ipython (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Downloading ipython-8.37.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: rich in /vol/home/s4181794/.local/lib/python3.10/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0) (14.1.0)
# Collecting matplotlib (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Downloading matplotlib-3.10.8-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Collecting librosa (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Downloading librosa-0.11.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: pystoi in /vol/home/s4181794/.local/lib/python3.10/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0) (0.4.1)
# Requirement already satisfied: torch_stoi in /vol/home/s4181794/.local/lib/python3.10/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0) (0.2.3)
# Requirement already satisfied: flatten-dict in /vol/home/s4181794/.local/lib/python3.10/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0) (0.4.2)
# Requirement already satisfied: markdown2 in /vol/home/s4181794/.local/lib/python3.10/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0) (2.5.4)
# Requirement already satisfied: randomname in /vol/home/s4181794/.local/lib/python3.10/site-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0) (0.2.1)
# Collecting protobuf>=4.0.0 (from capspeech==0.1.0)
#   Using cached protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting tqdm (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting filelock (from transformers<=4.46.1,>=4.46.1->capspeech==0.1.0)
#   Using cached filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting huggingface_hub (from capspeech==0.1.0)
#   Downloading huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Collecting pyyaml>=5.1 (from transformers<=4.46.1,>=4.46.1->capspeech==0.1.0)
#   Downloading pyyaml-6.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Collecting regex!=2019.12.17 (from transformers<=4.46.1,>=4.46.1->capspeech==0.1.0)
#   Downloading regex-2025.11.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Collecting requests (from transformers<=4.46.1,>=4.46.1->capspeech==0.1.0)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting safetensors>=0.4.1 (from transformers<=4.46.1,>=4.46.1->capspeech==0.1.0)
#   Using cached safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting tokenizers<0.21,>=0.20 (from transformers<=4.46.1,>=4.46.1->capspeech==0.1.0)
#   Downloading tokenizers-0.20.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting fsspec>=2023.5.0 (from huggingface_hub->capspeech==0.1.0)
#   Using cached fsspec-2025.12.0-py3-none-any.whl.metadata (10 kB)
# Collecting typing-extensions>=3.7.4.3 (from huggingface_hub->capspeech==0.1.0)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface_hub->capspeech==0.1.0)
#   Using cached hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting psutil (from accelerate->capspeech==0.1.0)
#   Using cached psutil-7.1.3-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl.metadata (23 kB)
# Collecting sympy>=1.13.3 (from torch->capspeech==0.1.0)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch->capspeech==0.1.0)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch->capspeech==0.1.0)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch->capspeech==0.1.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch->capspeech==0.1.0)
#   Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch->capspeech==0.1.0)
#   Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch->capspeech==0.1.0)
#   Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch->capspeech==0.1.0)
#   Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch->capspeech==0.1.0)
#   Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch->capspeech==0.1.0)
#   Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch->capspeech==0.1.0)
#   Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch->capspeech==0.1.0)
#   Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch->capspeech==0.1.0)
#   Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting nvidia-nccl-cu12==2.27.5 (from torch->capspeech==0.1.0)
#   Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvshmem-cu12==3.3.20 (from torch->capspeech==0.1.0)
#   Downloading nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch->capspeech==0.1.0)
#   Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch->capspeech==0.1.0)
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch->capspeech==0.1.0)
#   Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.5.1 (from torch->capspeech==0.1.0)
#   Downloading triton-3.5.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /vol/home/s4181794/.local/lib/python3.10/site-packages (from sympy>=1.13.3->torch->capspeech==0.1.0) (1.3.0)
# Requirement already satisfied: docstring-parser in /vol/home/s4181794/.local/lib/python3.10/site-packages (from argbind->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0) (0.17.0)
# Collecting rich (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Using cached rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting boto3<2.0,>=1.0 (from cached_path->capspeech==0.1.0)
#   Downloading boto3-1.42.9-py3-none-any.whl.metadata (6.8 kB)
# Collecting google-cloud-storage<3.0,>=1.32.0 (from cached_path->capspeech==0.1.0)
#   Downloading google_cloud_storage-2.19.0-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting botocore<1.43.0,>=1.42.9 (from boto3<2.0,>=1.0->cached_path->capspeech==0.1.0)
#   Downloading botocore-1.42.9-py3-none-any.whl.metadata (5.9 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2.0,>=1.0->cached_path->capspeech==0.1.0)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3<2.0,>=1.0->cached_path->capspeech==0.1.0)
#   Downloading s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting python-dateutil<3.0.0,>=2.1 (from botocore<1.43.0,>=1.42.9->boto3<2.0,>=1.0->cached_path->capspeech==0.1.0)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3!=2.2.0,<3,>=1.25.4 (from botocore<1.43.0,>=1.42.9->boto3<2.0,>=1.0->cached_path->capspeech==0.1.0)
#   Downloading urllib3-2.6.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting google-auth<3.0dev,>=2.26.1 (from google-cloud-storage<3.0,>=1.32.0->cached_path->capspeech==0.1.0)
#   Using cached google_auth-2.43.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting google-api-core<3.0.0dev,>=2.15.0 (from google-cloud-storage<3.0,>=1.32.0->cached_path->capspeech==0.1.0)
#   Downloading google_api_core-2.28.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting google-cloud-core<3.0dev,>=2.3.0 (from google-cloud-storage<3.0,>=1.32.0->cached_path->capspeech==0.1.0)
#   Downloading google_cloud_core-2.5.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-resumable-media>=2.7.2 (from google-cloud-storage<3.0,>=1.32.0->cached_path->capspeech==0.1.0)
#   Downloading google_resumable_media-2.8.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-crc32c<2.0dev,>=1.0 (from google-cloud-storage<3.0,>=1.32.0->cached_path->capspeech==0.1.0)
#   Downloading google_crc32c-1.8.0rc4-cp310-cp310-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (1.7 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage<3.0,>=1.32.0->cached_path->capspeech==0.1.0)
#   Downloading googleapis_common_protos-1.72.0-py3-none-any.whl.metadata (9.4 kB)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage<3.0,>=1.32.0->cached_path->capspeech==0.1.0)
#   Using cached proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting cachetools<7.0,>=2.0.0 (from google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached_path->capspeech==0.1.0)
#   Downloading cachetools-6.2.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached_path->capspeech==0.1.0)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached_path->capspeech==0.1.0)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting six>=1.5 (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.9->boto3<2.0,>=1.0->cached_path->capspeech==0.1.0)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting charset_normalizer<4,>=2 (from requests->transformers<=4.46.1,>=4.46.1->capspeech==0.1.0)
#   Downloading charset_normalizer-3.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests->transformers<=4.46.1,>=4.46.1->capspeech==0.1.0)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting certifi>=2017.4.17 (from requests->transformers<=4.46.1,>=4.46.1->capspeech==0.1.0)
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /vol/home/s4181794/.local/lib/python3.10/site-packages (from rich->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0) (4.0.0)
# Collecting pygments<3.0.0,>=2.13.0 (from rich->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Using cached pygments-2.19.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached_path->capspeech==0.1.0)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: mdurl~=0.1 in /vol/home/s4181794/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0) (0.1.2)
# Collecting pyarrow>=21.0.0 (from datasets->capspeech==0.1.0)
#   Using cached pyarrow-22.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.2 kB)
# Collecting dill<0.4.1,>=0.3.0 (from datasets->capspeech==0.1.0)
#   Using cached dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting pandas (from datasets->capspeech==0.1.0)
#   Downloading pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Collecting httpx<1.0.0 (from datasets->capspeech==0.1.0)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting xxhash (from datasets->capspeech==0.1.0)
#   Using cached xxhash-3.6.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.19 (from datasets->capspeech==0.1.0)
#   Downloading multiprocess-0.70.18-py310-none-any.whl.metadata (7.5 kB)
# Collecting fsspec>=2023.5.0 (from huggingface_hub->capspeech==0.1.0)
#   Downloading fsspec-2025.10.0-py3-none-any.whl.metadata (10 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets->capspeech==0.1.0)
#   Using cached aiohttp-3.13.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Collecting anyio (from httpx<1.0.0->datasets->capspeech==0.1.0)
#   Using cached anyio-4.12.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting httpcore==1.* (from httpx<1.0.0->datasets->capspeech==0.1.0)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1.0.0->datasets->capspeech==0.1.0)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets->capspeech==0.1.0)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets->capspeech==0.1.0)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets->capspeech==0.1.0)
#   Downloading async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets->capspeech==0.1.0)
#   Using cached attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets->capspeech==0.1.0)
#   Downloading frozenlist-1.8.0-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets->capspeech==0.1.0)
#   Downloading multidict-6.7.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets->capspeech==0.1.0)
#   Using cached propcache-0.4.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets->capspeech==0.1.0)
#   Using cached yarl-1.22.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (75 kB)
# Collecting exceptiongroup>=1.0.2 (from anyio->httpx<1.0.0->datasets->capspeech==0.1.0)
#   Downloading exceptiongroup-1.3.1-py3-none-any.whl.metadata (6.7 kB)
# Collecting einops (from descript-audio-codec->capspeech==0.1.0)
#   Using cached einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting nltk>=3.2.4 (from g2p_en->capspeech==0.1.0)
#   Downloading nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting inflect>=0.3.1 (from g2p_en->capspeech==0.1.0)
#   Downloading inflect-7.5.0-py3-none-any.whl.metadata (24 kB)
# Collecting distance>=0.1.3 (from g2p_en->capspeech==0.1.0)
#   Downloading Distance-0.1.3.tar.gz (180 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting more_itertools>=8.5.0 (from inflect>=0.3.1->g2p_en->capspeech==0.1.0)
#   Downloading more_itertools-10.8.0-py3-none-any.whl.metadata (39 kB)
# Collecting typeguard>=4.0.1 (from inflect>=0.3.1->g2p_en->capspeech==0.1.0)
#   Downloading typeguard-4.4.4-py3-none-any.whl.metadata (3.3 kB)
# Collecting click (from nltk>=3.2.4->g2p_en->capspeech==0.1.0)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: joblib in /vol/home/s4181794/.local/lib/python3.10/site-packages (from nltk>=3.2.4->g2p_en->capspeech==0.1.0) (1.5.2)
# Collecting decorator (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Using cached decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting jedi>=0.16 (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting matplotlib-inline (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Downloading matplotlib_inline-0.2.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting pexpect>4.3 (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting prompt_toolkit<3.1.0,>=3.0.41 (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Downloading prompt_toolkit-3.0.52-py3-none-any.whl.metadata (6.4 kB)
# Collecting stack_data (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Using cached stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting traitlets>=5.13.0 (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting wcwidth (from prompt_toolkit<3.1.0,>=3.0.41->ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Downloading wcwidth-0.2.14-py2.py3-none-any.whl.metadata (15 kB)
# Collecting parso<0.9.0,>=0.8.4 (from jedi>=0.16->ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Downloading parso-0.8.5-py2.py3-none-any.whl.metadata (8.3 kB)
# Collecting ptyprocess>=0.5 (from pexpect>4.3->ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /vol/home/s4181794/.local/lib/python3.10/site-packages (from jinja2->torch->capspeech==0.1.0) (3.0.2)
# Collecting rapidfuzz>=3.9.7 (from jiwer->capspeech==0.1.0)
#   Downloading rapidfuzz-3.14.3-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Collecting numpy (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting torchlibrosa (from laion_clap->capspeech==0.1.0)
#   Downloading torchlibrosa-0.1.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting ftfy (from laion_clap->capspeech==0.1.0)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting braceexpand (from laion_clap->capspeech==0.1.0)
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting webdataset (from laion_clap->capspeech==0.1.0)
#   Downloading webdataset-1.0.2-py3-none-any.whl.metadata (12 kB)
# Collecting wget (from laion_clap->capspeech==0.1.0)
#   Using cached wget-3.2-py3-none-any.whl
# Collecting llvmlite (from laion_clap->capspeech==0.1.0)
#   Downloading llvmlite-0.46.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.0 kB)
# Collecting scikit-learn (from laion_clap->capspeech==0.1.0)
#   Downloading scikit_learn-1.7.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: h5py in /vol/home/s4181794/.local/lib/python3.10/site-packages (from laion_clap->capspeech==0.1.0) (3.14.0)
# Collecting progressbar (from laion_clap->capspeech==0.1.0)
#   Downloading progressbar-2.5.tar.gz (10 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: audioread>=2.1.9 in /vol/home/s4181794/.local/lib/python3.10/site-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0) (3.1.0)
# Collecting numba>=0.51.0 (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Downloading numba-0.63.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.9 kB)
# Requirement already satisfied: pooch>=1.1 in /vol/home/s4181794/.local/lib/python3.10/site-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /vol/home/s4181794/.local/lib/python3.10/site-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0) (1.0.0)
# Requirement already satisfied: lazy_loader>=0.1 in /vol/home/s4181794/.local/lib/python3.10/site-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0) (0.4)
# Collecting msgpack>=1.0 (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Downloading msgpack-1.1.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Collecting platformdirs>=2.5.0 (from pooch>=1.1->librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Using cached platformdirs-4.5.1-py3-none-any.whl.metadata (12 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->laion_clap->capspeech==0.1.0)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting cffi>=1.0 (from soundfile->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Downloading cffi-2.0.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=1.0->soundfile->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Using cached pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Collecting contourpy>=1.0.1 (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Using cached contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Using cached fonttools-4.61.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Using cached kiwisolver-1.4.9-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.3 kB)
# Collecting pillow>=8 (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Using cached pillow-12.0.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Collecting pytz>=2020.1 (from pandas->datasets->capspeech==0.1.0)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->datasets->capspeech==0.1.0)
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting future>=0.16.0 (from pyloudnorm->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Using cached future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting fire (from randomname->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Downloading fire-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: termcolor in /vol/home/s4181794/.local/lib/python3.10/site-packages (from fire->randomname->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0) (3.1.0)
# Collecting executing>=1.2.0 (from stack_data->ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Downloading executing-2.2.1-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data->ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Downloading asttokens-3.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting pure-eval (from stack_data->ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->capspeech==0.1.0)
#   Using cached pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting absl-py>=0.4 (from tensorboard->capspeech==0.1.0)
#   Using cached absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: grpcio>=1.48.2 in /vol/home/s4181794/.local/lib/python3.10/site-packages (from tensorboard->capspeech==0.1.0) (1.75.0)
# Collecting markdown>=2.6.8 (from tensorboard->capspeech==0.1.0)
#   Using cached markdown-3.10-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: setuptools>=41.0.0 in /vol/home/s4181794/miniconda3/envs/CapTTS/lib/python3.10/site-packages (from tensorboard->capspeech==0.1.0) (80.9.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /vol/home/s4181794/.local/lib/python3.10/site-packages (from tensorboard->capspeech==0.1.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /vol/home/s4181794/.local/lib/python3.10/site-packages (from tensorboard->capspeech==0.1.0) (3.1.3)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics->capspeech==0.1.0)
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb->capspeech==0.1.0)
#   Using cached gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Collecting pydantic<3 (from wandb->capspeech==0.1.0)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting sentry-sdk>=2.0.0 (from wandb->capspeech==0.1.0)
#   Using cached sentry_sdk-2.47.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3->wandb->capspeech==0.1.0)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3->wandb->capspeech==0.1.0)
#   Downloading pydantic_core-2.41.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3->wandb->capspeech==0.1.0)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb->capspeech==0.1.0)
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->capspeech==0.1.0)
#   Using cached smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting einx>=0.3.0 (from x_transformers->capspeech==0.1.0)
#   Downloading einx-0.3.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting loguru (from x_transformers->capspeech==0.1.0)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting frozendict (from einx>=0.3.0->x_transformers->capspeech==0.1.0)
#   Downloading frozendict-2.4.7-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (23 kB)
# Using cached protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Downloading transformers-4.46.1-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 25.0 MB/s  0:00:00eta 0:00:01
# Downloading huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.1/566.1 kB 14.2 MB/s  0:00:00
# Using cached hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# Downloading tokenizers-0.20.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 35.7 MB/s  0:00:00
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Downloading pyyaml-6.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (770 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.3/770.3 kB 18.0 MB/s  0:00:00
# Downloading regex-2025.11.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (791 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 791.7/791.7 kB 19.5 MB/s  0:00:00
# Using cached safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (507 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading accelerate-1.12.0-py3-none-any.whl (380 kB)
# Downloading torch-2.9.1-cp310-cp310-manylinux_2_28_x86_64.whl (899.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.8/899.8 MB 19.2 MB/s  0:00:27m0:00:0100:01
# Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 24.8 MB/s  0:00:16m0:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 17.6 MB/s  0:00:00eta 0:00:01
# Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 31.7 MB/s  0:00:02m0:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 20.3 MB/s  0:00:00
# Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 29.0 MB/s  0:00:14m0:00:0100:01
# Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 40.8 MB/s  0:00:04m0:00:0100:01
# Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 25.2 MB/s  0:00:00
# Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 52.8 MB/s  0:00:016m0:00:0100:01
# Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 40.1 MB/s  0:00:06m0:00:0100:01
# Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 41.5 MB/s  0:00:06m0:00:0100:01
# Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 40.3 MB/s  0:00:07m0:00:0100:01
# Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 41.5 MB/s  0:00:07m0:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 47.4 MB/s  0:00:00m0:00:0100:01m
# Downloading nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (124.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 MB 42.5 MB/s  0:00:02m0:00:0100:01
# Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading triton-3.5.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (170.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.3/170.3 MB 42.6 MB/s  0:00:03m0:00:0100:01
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Downloading cached_path-1.8.0-py3-none-any.whl (37 kB)
# Downloading boto3-1.42.9-py3-none-any.whl (140 kB)
# Downloading botocore-1.42.9-py3-none-any.whl (14.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 52.0 MB/s  0:00:006m0:00:01
# Using cached filelock-3.20.0-py3-none-any.whl (16 kB)
# Downloading google_cloud_storage-2.19.0-py2.py3-none-any.whl (131 kB)
# Downloading google_api_core-2.28.1-py3-none-any.whl (173 kB)
# Using cached google_auth-2.43.0-py2.py3-none-any.whl (223 kB)
# Downloading cachetools-6.2.3-py3-none-any.whl (11 kB)
# Downloading google_cloud_core-2.5.0-py3-none-any.whl (29 kB)
# Downloading google_crc32c-1.8.0rc4-cp310-cp310-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (33 kB)
# Downloading googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Using cached proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached rich-13.9.4-py3-none-any.whl (242 kB)
# Using cached pygments-2.19.2-py3-none-any.whl (1.2 MB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
# Downloading urllib3-2.6.2-py3-none-any.whl (131 kB)
# Using cached certifi-2025.11.12-py3-none-any.whl (159 kB)
# Downloading google_resumable_media-2.8.0-py3-none-any.whl (81 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading datasets-4.4.1-py3-none-any.whl (511 kB)
# Using cached dill-0.4.0-py3-none-any.whl (119 kB)
# Downloading fsspec-2025.10.0-py3-none-any.whl (200 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading multiprocess-0.70.18-py310-none-any.whl (134 kB)
# Using cached aiohttp-3.13.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
# Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Downloading multidict-6.7.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (241 kB)
# Using cached yarl-1.22.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (346 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-25.4.0-py3-none-any.whl (67 kB)
# Downloading frozenlist-1.8.0-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (219 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached propcache-0.4.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (196 kB)
# Using cached pyarrow-22.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (47.6 MB)
# Using cached anyio-4.12.0-py3-none-any.whl (113 kB)
# Downloading exceptiongroup-1.3.1-py3-none-any.whl (16 kB)
# Using cached einops-0.8.1-py3-none-any.whl (64 kB)
# Downloading ema_pytorch-0.7.7-py3-none-any.whl (9.8 kB)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
# Downloading ffmpy-1.0.0-py3-none-any.whl (5.6 kB)
# Downloading g2p_en-2.1.0-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 40.6 MB/s  0:00:00
# Downloading inflect-7.5.0-py3-none-any.whl (35 kB)
# Downloading more_itertools-10.8.0-py3-none-any.whl (69 kB)
# Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 31.3 MB/s  0:00:00
# Downloading typeguard-4.4.4-py3-none-any.whl (34 kB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Downloading ipython-8.37.0-py3-none-any.whl (831 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.9/831.9 kB 17.5 MB/s  0:00:00
# Downloading prompt_toolkit-3.0.52-py3-none-any.whl (391 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 31.9 MB/s  0:00:00
# Downloading parso-0.8.5-py2.py3-none-any.whl (106 kB)
# Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
# Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
# Using cached decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading jiwer-4.0.0-py3-none-any.whl (23 kB)
# Downloading rapidfuzz-3.14.3-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 37.7 MB/s  0:00:00
# Downloading laion_clap-1.1.7-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 5.7 MB/s  0:00:00 eta 0:00:01
# Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
# Downloading librosa-0.11.0-py3-none-any.whl (260 kB)
# Downloading msgpack-1.1.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (406 kB)
# Downloading numba-0.63.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 35.1 MB/s  0:00:00
# Downloading llvmlite-0.46.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 34.7 MB/s  0:00:01m0:00:0100:01
# Using cached platformdirs-4.5.1-py3-none-any.whl (18 kB)
# Downloading scikit_learn-1.7.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 43.8 MB/s  0:00:00m0:00:01
# Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 51.2 MB/s  0:00:006m0:00:0100:01
# Downloading soundfile-0.13.1-py2.py3-none-manylinux_2_28_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 23.3 MB/s  0:00:00
# Downloading cffi-2.0.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading matplotlib-3.10.8-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 49.1 MB/s  0:00:00
# Using cached contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.61.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.9 MB)
# Using cached kiwisolver-1.4.9-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Using cached pillow-12.0.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
# Using cached pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Downloading matplotlib_inline-0.2.1-py3-none-any.whl (9.5 kB)
# Using cached ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
# Downloading pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 50.7 MB/s  0:00:006m0:00:01
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Using cached psutil-7.1.3-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl (263 kB)
# Using cached pycparser-2.23-py3-none-any.whl (118 kB)
# Using cached future-1.0.0-py3-none-any.whl (491 kB)
# Downloading pypinyin-0.55.0-py2.py3-none-any.whl (840 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.2/840.2 kB 20.7 MB/s  0:00:00
# Downloading fire-0.7.1-py3-none-any.whl (115 kB)
# Downloading sentencepiece-0.2.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 14.7 MB/s  0:00:00
# Using cached stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading asttokens-3.0.1-py3-none-any.whl (27 kB)
# Downloading executing-2.2.1-py2.py3-none-any.whl (28 kB)
# Using cached pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Using cached tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
# Using cached absl_py-2.3.1-py3-none-any.whl (135 kB)
# Using cached markdown-3.10-py3-none-any.whl (107 kB)
# Downloading torchaudio-2.9.1-cp310-cp310-manylinux_2_28_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 37.8 MB/s  0:00:00
# Downloading torchdiffeq-0.2.5-py3-none-any.whl (32 kB)
# Downloading torchlibrosa-0.1.0-py3-none-any.whl (11 kB)
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 24.2 MB/s  0:00:00
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading torchvision-0.24.1-cp310-cp310-manylinux_2_28_x86_64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 35.9 MB/s  0:00:00m0:00:01
# Downloading wandb-0.23.1-py3-none-manylinux_2_28_x86_64.whl (22.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.9/22.9 MB 38.1 MB/s  0:00:00m0:00:0100:01
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 36.0 MB/s  0:00:00
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached gitpython-3.1.45-py3-none-any.whl (208 kB)
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
# Using cached sentry_sdk-2.47.0-py2.py3-none-any.whl (411 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading wcwidth-0.2.14-py2.py3-none-any.whl (37 kB)
# Downloading webdataset-1.0.2-py3-none-any.whl (74 kB)
# Downloading x_transformers-2.11.24-py3-none-any.whl (100 kB)
# Downloading einx-0.3.0-py3-none-any.whl (102 kB)
# Downloading frozendict-2.4.7-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (120 kB)
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
# Downloading xformers-0.0.33.post2-cp39-abi3-manylinux_2_28_x86_64.whl (122.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.9/122.9 MB 45.7 MB/s  0:00:02m0:00:0100:01
# Using cached xxhash-3.6.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (193 kB)
# Building wheels for collected packages: capspeech, descript-audiotools, distance, progressbar
#   Building wheel for capspeech (pyproject.toml) ... done
#   Created wheel for capspeech: filename=capspeech-0.1.0-py3-none-any.whl size=227017 sha256=d60c52ad645a6a4849346559c415b8d4fa34f6c27c51b0556e682fdcbabfb038
#   Stored in directory: /tmp/pip-ephem-wheel-cache-p01tqg64/wheels/1f/9d/66/3a093fff1ca54b85a5a652860a4a6fe1e02874796910f3b5e9
#   Building wheel for descript-audiotools (pyproject.toml) ... done
#   Created wheel for descript-audiotools: filename=descript_audiotools-0.7.4-py2.py3-none-any.whl size=108005 sha256=6103393ee86a39ea90b1473fc5701d88b67732df41c7319139cab4d419889895
#   Stored in directory: /tmp/pip-ephem-wheel-cache-p01tqg64/wheels/58/20/2e/8d6d45b762646f67a787680fb04b9b248929d59f46f66d4a0f
#   Building wheel for distance (pyproject.toml) ... done
#   Created wheel for distance: filename=distance-0.1.3-py3-none-any.whl size=16321 sha256=449853325609dad26fe114a75c0566f8a9321d8c0c190270f68d99ce1e2592bb
#   Stored in directory: /vol/home/s4181794/.cache/pip/wheels/e8/bb/de/f71bf63559ea9a921059a5405806f7ff6ed612a9231c4a9309
#   Building wheel for progressbar (pyproject.toml) ... done
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12144 sha256=d2ac304822c0b7dbbc06dcedbde98fc1ef0dc8a0c6308cb9ad3b4bde6d7c7bc3
#   Stored in directory: /vol/home/s4181794/.cache/pip/wheels/cd/17/e5/765d1a3112ff3978f70223502f6047e06c43a24d7c5f8ff95b
# Successfully built capspeech descript-audiotools distance progressbar
# Installing collected packages: wget, pytz, pure-eval, ptyprocess, progressbar, nvidia-cusparselt-cu12, jieba, distance, braceexpand, xxhash, wcwidth, urllib3, tzdata, typing-extensions, triton, traitlets, tqdm, threadpoolctl, sympy, smmap, six, sentencepiece, safetensors, regex, rapidfuzz, pyyaml, pypinyin, pyparsing, pygments, pycparser, pyasn1, pyarrow, psutil, protobuf, propcache, platformdirs, pillow, pexpect, parso, packaging, nvidia-nvtx-cu12, nvidia-nvshmem-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, ninja, networkx, msgpack, more_itertools, markdown, loguru, llvmlite, kiwisolver, jmespath, jinja2, idna, hf-xet, h11, google-crc32c, future, fsspec, frozenlist, frozendict, fonttools, fire, filelock, ffmpy, executing, einops, dill, decorator, cycler, click, charset_normalizer, certifi, cachetools, attrs, async-timeout, asttokens, annotated-types, aiohappyeyeballs, absl-py, webdataset, typing-inspection, typeguard, stack_data, sentry-sdk, scipy, rsa, rich, requests, python-dateutil, pydantic-core, pyasn1-modules, proto-plus, prompt_toolkit, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, numba, nltk, multiprocess, multidict, matplotlib-inline, lightning-utilities, jiwer, jedi, httpcore, googleapis-common-protos, google-resumable-media, gitdb, ftfy, exceptiongroup, einx, contourpy, cffi, aiosignal, yarl, tensorboard, soundfile, scikit-learn, pydantic, pandas, nvidia-cusolver-cu12, matplotlib, ipython, inflect, huggingface_hub, google-auth, gitpython, botocore, anyio, wandb, torch, tokenizers, s3transfer, librosa, httpx, google-api-core, g2p_en, aiohttp, xformers, x_transformers, transformers, torchvision, torchmetrics, torchlibrosa, torchdiffeq, torchaudio, google-cloud-core, ema_pytorch, boto3, accelerate, laion_clap, google-cloud-storage, datasets, evaluate, descript-audiotools, cached_path, capspeech
#   Attempting uninstall: nvidia-cusparselt-cu12━━━━━━━━━━━   4/166 [progressbar]
#     Found existing installation: nvidia-cusparselt-cu12 0.6.22m  4/166 [progressbar]
#     Uninstalling nvidia-cusparselt-cu12-0.6.2:━━━━━━━   4/166 [progressbar]
#       Successfully uninstalled nvidia-cusparselt-cu12-0.6.2  4/166 [progressbar]
#   Attempting uninstall: sympym━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  16/166 [tqdm]lets]ensions]cu12]
#     Found existing installation: sympy 1.13.1━━━━━━━━━━━━━━━━━  16/166 [tqdm]
#     Uninstalling sympy-1.13.1:m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  18/166 [sympy]
#       Successfully uninstalled sympy-1.13.1━━━━━━━━━━━━━━━━━━━━━━━  18/166 [sympy]
#   Attempting uninstall: nvidia-nvjitlink-cu12━━━━━━━━━━━━━━━━━━━━━  41/166 [nvidia-nvshmem-cu12]
#     Found existing installation: nvidia-nvjitlink-cu12 12.4.127  41/166 [nvidia-nvshmem-cu12]
#     Uninstalling nvidia-nvjitlink-cu12-12.4.127:━━━━━━━━━━━━━━  41/166 [nvidia-nvshmem-cu12]
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.4.127━  41/166 [nvidia-nvshmem-cu12]
#   Attempting uninstall: rich━━╸━━━━━━━━━━━━━━━━━  94/166 [rsa]y]-sdk]ection]]u12]2]
#     Found existing installation: rich 14.1.0m━━━━━━━━━━━━━━━━━  94/166 [rsa]
#     Uninstalling rich-14.1.0:━╸━━━━━━━━━━━━━━━━━  95/166 [rich]
#       Successfully uninstalled rich-14.1.090m━━━━━━━━━━━━━━━━━  95/166 [rich]
#   Attempting uninstall: nvidia-cudnn-cu12╸━━━━━━━━━━━━━━━ 103/166 [nvidia-cufft-cu12]12]
#     Found existing installation: nvidia-cudnn-cu12 9.1.0.70━━━ 103/166 [nvidia-cufft-cu12]
#     Uninstalling nvidia-cudnn-cu12-9.1.0.70:90m━━━━━━━━━━━━━━━ 103/166 [nvidia-cufft-cu12]
#       Successfully uninstalled nvidia-cudnn-cu12-9.1.0.70━━━━━ 103/166 [nvidia-cufft-cu12]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━ 105/166 [numba]-cudnn-cu12]

# %% [markdown]
# ## 🔥 Step 2: Load packages

# %%
import torch
import capspeech.nar.generate as nar
from transformers import AutoTokenizer, set_seed
import soundfile as sf
import time
import os
from huggingface_hub import snapshot_download
import argparse
from IPython.display import Audio, display

device = "cuda:0" if torch.cuda.is_available() else "cpu"
print(f"Device: {device}")
nar.seed_everything(42) # change to your favorite seed

# %% [markdown]
# ## 🔥 Step 3: Customize your input

# %%
# You can change to any duration you want
duration = None 
# Change to your transcript
transcript = "Use hir or ze as gender neutral pronouns?" 
# Change to your style caption
caption = "A male speaker delivers his words in a measured pace, exhibiting a high-pitched, happy, and animated tone in a clean environment."

# %% [markdown]
# ## 🔥 Step 4: Generate
#
# ⏳ The first run may take some time as it needs to download the pretrained checkpoints.

# %%
model_list = nar.load_model(device, "CapTTS")
audio_arr = nar.run(model_list, device, duration, transcript, caption)
Audio(audio_arr, rate=24000)
